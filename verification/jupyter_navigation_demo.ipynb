# %% [markdown]
# # Jupyter Navigation Demo
# Notebook created in the project verification folder.

# %%
project = 'S81-tokyoriders-AgroLens'
print('Notebook execution OK for', project)
print('2 + 3 =', 2 + 3)
# Out:
# Notebook execution OK for S81-tokyoriders-AgroLens
# 2 + 3 = 5
